# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# # Reading data

# %%
file_path = 'AAPL.csv'
dataDF = pd.read_csv(file_path)

# %% [markdown]
# # Adding "day_of_week" column

# %%
dataDF['Date'] = pd.to_datetime(dataDF['Date'])
dataDF['day_of_week'] = dataDF['Date'].dt.weekday_name

# %%
dataDF.head(10)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-07-09  189.500000  190.679993  189.300003  190.580002  190.580002
# 1 2018-07-10  190.710007  191.279999  190.179993  190.350006  190.350006
# 2 2018-07-11  188.500000  189.779999  187.610001  187.880005  187.880005
# 3 2018-07-12  189.529999  191.410004  189.309998  191.029999  191.029999
# 4 2018-07-13  191.080002  191.839996  190.899994  191.330002  191.330002
# 5 2018-07-16  191.520004  192.649994  190.419998  190.910004  190.910004
# 6 2018-07-17  189.750000  191.869995  189.199997  191.449997  191.449997
# 7 2018-07-18  191.779999  191.800003  189.929993  190.399994  190.399994
# 8 2018-07-19  189.690002  192.550003  189.690002  191.880005  191.880005
# 9 2018-07-20  191.779999  192.429993  190.169998  191.440002  191.440002
#
#      Volume day_of_week
# 0  19756600      Monday
# 1  15939100     Tuesday
# 2  18831500   Wednesday
# 3  18041100    Thursday
# 4  12513900      Friday
# 5  15043100      Monday
# 6  15534500     Tuesday
# 7  16393400   Wednesday
# 8  20286800    Thursday
# 9  20676200      Friday

# %% [markdown]
# # Adding "same_day_delta" column

# %%
dataDF['same_day_deta'] = dataDF['Open'].sub(dataDF['Close']).apply(lambda x:x/100)

# %%
dataDF['same_day_deta'].head(10)
# Out:
# 0   -0.0108
# 1    0.0036
# 2    0.0062
# 3   -0.0150
# 4   -0.0025
# 5    0.0061
# 6   -0.0170
# 7    0.0138
# 8   -0.0219
# 9    0.0034
# Name: same_day_deta, dtype: float64

# %% [markdown]
# # Adding "same_day_strategy" column

# %%
dataDF['same_day_strategy'] = dataDF['same_day_deta'].apply(lambda x: 1 if x > 0.0 else 0)

# %% [markdown]
# # Adding "next_close_delta" column

# %%
def percentageChange(df, columnName):
    df['next_close_delta'] = np.nan
    for index in range(df.shape[0]):
        if(index == 0):
            continue
        else:
            df.at[index,'next_close_delta'] = ((df[columnName][index] - df[columnName][index-1]) / df[columnName][index])*100

# %%
percentageChange(dataDF, 'Close')

# %% [markdown]
# # Adding "next_column_strategy" column

# %%
dataDF['next_column_strategy'] = np.where(dataDF['next_close_delta']<=0.1, 0, 1)

# %%
dataDF
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-07-09  189.500000  190.679993  189.300003  190.580002  190.580002
# 1  2018-07-10  190.710007  191.279999  190.179993  190.350006  190.350006
# 2  2018-07-11  188.500000  189.779999  187.610001  187.880005  187.880005
# 3  2018-07-12  189.529999  191.410004  189.309998  191.029999  191.029999
# 4  2018-07-13  191.080002  191.839996  190.899994  191.330002  191.330002
# 5  2018-07-16  191.520004  192.649994  190.419998  190.910004  190.910004
# 6  2018-07-17  189.750000  191.869995  189.199997  191.449997  191.449997
# 7  2018-07-18  191.779999  191.800003  189.929993  190.399994  190.399994
# 8  2018-07-19  189.690002  192.550003  189.690002  191.880005  191.880005
# 9  2018-07-20  191.779999  192.429993  190.169998  191.440002  191.440002
# 10 2018-07-23  190.679993  191.960007  189.559998  191.610001  191.610001
# 11 2018-07-24  192.449997  193.660004  192.050003  193.000000  193.000000
# 12 2018-07-25  193.059998  194.850006  192.429993  194.820007  194.820007
# 13 2018-07-26  194.610001  195.960007  193.610001  194.210007  194.210007
# 14 2018-07-27  194.990005  195.190002  190.100006  190.979996  190.979996
# 15 2018-07-30  191.899994  192.199997  189.070007  189.910004  189.910004
# 16 2018-07-31  190.300003  192.139999  189.339996  190.289993  190.289993
# 17 2018-08-01  199.130005  201.759995  197.309998  201.500000  201.500000
# 18 2018-08-02  200.580002  208.380005  200.350006  207.389999  207.389999
# 19 2018-08-03  207.029999  208.740005  205.479996  207.990005  207.990005
# 20 2018-08-06  208.000000  209.250000  207.070007  209.070007  209.070007
#
#       Volume day_of_week  same_day_deta  same_day_strategy  next_close_delta  \
# 0   19756600      Monday        -0.0108                  0               NaN
# 1   15939100     Tuesday         0.0036                  1         -0.120828
# 2   18831500   Wednesday         0.0062                  1         -1.314669
# 3   18041100    Thursday        -0.0150                  0          1.648953
# 4   12513900      Friday        -0.0025                  0          0.156799
# 5   15043100      Monday         0.0061                  1         -0.219998
# 6   15534500     Tuesday        -0.0170                  0          0.282054
# 7   16393400   Wednesday         0.0138                  1         -0.551472
# 8   20286800    Thursday        -0.0219                  0          0.771321
# 9   20676200      Friday         0.0034                  1         -0.229839
# 10  15989400      Monday        -0.0093                  0          0.088721
# 11  18697900     Tuesday        -0.0055                  0          0.720207
# 12  16709900   Wednesday        -0.0176                  0          0.934199
# 13  19076000    Thursday         0.0040                  1         -0.314093
# 14  24024000      Friday         0.0401                  1         -1.691282
# 15  21029500      Monday         0.0199                  1         -0.563421
# 16  39373000     Tuesday         0.0001                  1          0.199689
# 17  67935700   Wednesday        -0.0237                  0          5.563279
# 18  62404000    Thursday        -0.0681                  0          2.840059
# 19  33447400      Friday        -0.0096                  0          0.288478
# 20  25398800      Monday        -0.0107                  0          0.516574
#
#     next_column_strategy
# 0                      1
# 1                      0
# 2                      0
# 3                      1
# 4                      1
# 5                      0
# 6                      1
# 7                      0
# 8                      1
# 9                      0
# 10                     0
# 11                     1
# 12                     1
# 13                     0
# 14                     0
# 15                     0
# 16                     1
# 17                     1
# 18                     1
# 19                     1
# 20                     1

# %% [markdown]
# # monthly_analysis.csv

# %%
monthly_analysis = pd.DataFrame({'Average_close_price':dataDF.groupby(pd.to_datetime(dataDF['Date']).dt.strftime('%B'))['Close'].mean(),
             'Average_open_price':dataDF.groupby(pd.to_datetime(dataDF['Date']).dt.strftime('%B'))['Open'].mean(),
             'Highest_close_price':dataDF.groupby(pd.to_datetime(dataDF['Date']).dt.strftime('%B'))['Close'].max(),
             'Lowest_open_price':dataDF.groupby(pd.to_datetime(dataDF['Date']).dt.strftime('%B'))['Open'].min(),
             'Highest_high':dataDF.groupby(pd.to_datetime(dataDF['Date']).dt.strftime('%B'))['High'].max(),
             'Highest_low':dataDF.groupby(pd.to_datetime(dataDF['Date']).dt.strftime('%B'))['Low'].max(),
             'Lowest_high':dataDF.groupby(pd.to_datetime(dataDF['Date']).dt.strftime('%B'))['High'].min(),
             'Lowest_low': dataDF.groupby(pd.to_datetime(dataDF['Date']).dt.strftime('%B'))['Low'].min()})

monthly_analysis.to_csv('monthly_analysis.csv', sep=',')

# %% [markdown]
# # plot Open and Close prices

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import numpy as np

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
trace1 = go.Scatter(
                    x = dataDF.Date,
                    y = dataDF.Close,
                    mode = "lines",
                    name = "Close",
                    marker = dict(color = '#17BECF'))

trace2 = go.Scatter(
                    x = dataDF.Date,
                    y = dataDF.Open,
                    mode = "lines+markers",
                    name = "Open",
                    marker = dict(color = '#7F7F7F'))
data = [trace1, trace2]
layout = dict(title = 'Open and Close prices vs date',
              xaxis= dict(title= 'Date',ticklen= 5,zeroline= True))
fig = dict(data = data, layout = layout)
iplot(fig,filename="Open and Close prices")
# Out:
# <div id="e5208830-609a-435e-9e54-59a5c8b3694c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e5208830-609a-435e-9e54-59a5c8b3694c", [{"name": "Close", "marker": {"color": "#17BECF"}, "mode": "lines", "y": [190.580002, 190.350006, 187.880005, 191.029999, 191.330002, 190.91000400000001, 191.449997, 190.399994, 191.880005, 191.440002, 191.610001, 193.0, 194.820007, 194.21000700000002, 190.979996, 189.91000400000001, 190.28999299999998, 201.5, 207.389999, 207.990005, 209.070007], "x": ["2018-07-09", "2018-07-10", "2018-07-11", "2018-07-12", "2018-07-13", "2018-07-16", "2018-07-17", "2018-07-18", "2018-07-19", "2018-07-20", "2018-07-23", "2018-07-24", "2018-07-25", "2018-07-26", "2018-07-27", "2018-07-30", "2018-07-31", "2018-08-01", "2018-08-02", "2018-08-03", "2018-08-06"], "type": "scatter", "uid": "241f5dbe-9ca8-11e8-8366-d053494eb1af"}, {"name": "Open", "marker": {"color": "#7F7F7F"}, "mode": "lines+markers", "y": [189.5, 190.71000700000002, 188.5, 189.529999, 191.080002, 191.520004, 189.75, 191.779999, 189.690002, 191.779999, 190.679993, 192.449997, 193.059998, 194.610001, 194.990005, 191.899994, 190.300003, 199.130005, 200.580002, 207.029999, 208.0], "x": ["2018-07-09", "2018-07-10", "2018-07-11", "2018-07-12", "2018-07-13", "2018-07-16", "2018-07-17", "2018-07-18", "2018-07-19", "2018-07-20", "2018-07-23", "2018-07-24", "2018-07-25", "2018-07-26", "2018-07-27", "2018-07-30", "2018-07-31", "2018-08-01", "2018-08-02", "2018-08-03", "2018-08-06"], "type": "scatter", "uid": "241f5dbf-9ca8-11e8-8366-d053494eb1af"}], {"xaxis": {"zeroline": true, "ticklen": 5, "title": "Date"}, "title": "Open and Close prices vs date"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# # plot "same_day_delta"

# %%
trace1 = go.Scatter(
                    x = dataDF.Date,
                    y = dataDF.same_day_deta,
                    mode = "lines",
                    name = "Close",
                    marker = dict(color = '#17BECF'))

data = [trace1]
layout = dict(title = 'same_day_delta',
              xaxis= dict(title= 'Date',ticklen= 5,zeroline= True))
fig = dict(data = data, layout = layout)
iplot(fig, filename="same_day_delta")
# Out:
# <div id="b928ae70-923e-4b9c-addb-2aefb5011bfa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b928ae70-923e-4b9c-addb-2aefb5011bfa", [{"name": "Close", "marker": {"color": "#17BECF"}, "mode": "lines", "y": [-0.010800020000000075, 0.0036000100000001113, 0.006199949999999887, -0.015, -0.0025, 0.006099999999999852, -0.01699996999999996, 0.013800050000000112, -0.021900030000000185, 0.0033999700000001097, -0.00930008000000015, -0.005500030000000038, -0.017600089999999968, 0.003999939999999924, 0.04010008999999996, 0.019899899999999776, 0.000100100000000225, -0.023699949999999886, -0.06809996999999982, -0.009600059999999928, -0.010700070000000039], "x": ["2018-07-09", "2018-07-10", "2018-07-11", "2018-07-12", "2018-07-13", "2018-07-16", "2018-07-17", "2018-07-18", "2018-07-19", "2018-07-20", "2018-07-23", "2018-07-24", "2018-07-25", "2018-07-26", "2018-07-27", "2018-07-30", "2018-07-31", "2018-08-01", "2018-08-02", "2018-08-03", "2018-08-06"], "type": "scatter", "uid": "26ebccc5-9ca8-11e8-8366-d053494eb1af"}], {"xaxis": {"zeroline": true, "ticklen": 5, "title": "Date"}, "title": "same_day_delta"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# # plot "same_day_delta" distplot

# %%
import plotly.figure_factory as ff

labels = ['distplot']
fig = ff.create_distplot([dataDF.same_day_deta],labels)
iplot(fig, filename="same_day_delta dist")
# Out:
# <div id="bcc68456-55d7-4475-93b1-4618aa8a063f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'bcc68456-55d7-4475-93b1-4618aa8a063f',
#             [{"opacity": 0.7, "legendgroup": "distplot", "autobinx": false, "name": "distplot", "yaxis": "y", "histnorm": "probability density", "xaxis": "x", "xbins": {"start": -0.06809996999999982, "end": 0.04010008999999996, "size": 1.0}, "marker": {"color": "rgb(31, 119, 180)"}, "x": [-0.010800020000000075, 0.0036000100000001113, 0.006199949999999887, -0.015, -0.0025, 0.006099999999999852, -0.01699996999999996, 0.013800050000000112, -0.021900030000000185, 0.0033999700000001097, -0.00930008000000015, -0.005500030000000038, -0.017600089999999968, 0.003999939999999924, 0.04010008999999996, 0.019899899999999776, 0.000100100000000225, -0.023699949999999886, -0.06809996999999982, -0.009600059999999928, -0.010700070000000039], "type": "histogram", "uid": "2a6a44c0-9ca8-11e8-8366-d053494eb1af"}, {"showlegend": false, "legendgroup": "distplot", "name": "distplot", "yaxis": "y", "marker": {"color": "rgb(31, 119, 180)"}, "mode": "lines", "xaxis": "x", "y": [1.6821056059838746, 1.6819045145175193, 1.6810957895521141, 1.6796810137079283, 1.6776624806081522, 1.6750431938126749, 1.671826864619369, 1.6680179087469946, 1.663621441916945, 1.6586432743541109, 1.6530899042301272, 1.6469685100751832, 1.6402869421874045, 1.6330537130715566, 1.625277986941446, 1.6169695683229157, 1.6081388897967321, 1.5987969989229227, 1.588955544390263, 1.5786267614365823, 1.5678234565874152, 1.5565589917621687, 1.5448472677985268, 1.5327027074471247, 1.5201402378897204, 1.5071752728350756, 1.4938236942475718, 1.480101833764239, 1.46602645385629, 1.451614728791553, 1.4368842254542495, 1.4218528840784626, 1.4065389989513462, 1.3909611991416535, 1.3751384293084898, 1.359089930644364, 1.3428352220055986, 1.3263940812819617, 1.3097865270560287, 1.2930328006012592, 1.2761533482661125, 1.2591688042896527, 1.2420999740921699, 1.2249678180821781, 1.207793436018942, 1.1905980519672816, 1.17340299987894, 1.156229709832185, 1.1390996949586325, 1.1220345390834856, 1.1050558851025283, 1.0881854241162632, 1.0714448853385927, 1.0548560267943832, 1.0384406268171735, 1.0222204763551384, 1.006217372090295, 0.9904531103727567, 0.9749494819686911, 0.9597282676174745, 0.9448112343903904, 0.9302201328401234, 0.9159766949271987, 0.9021026327065079, 0.8886196377540738, 0.8755493813112941, 0.862913515121068, 0.8507336729274433, 0.8390314726077657, 0.8278285189037103, 0.8171464067151424, 0.8070067249183647, 0.7974310606680891, 0.7884410041403525, 0.7800581536716042, 0.7723041212473636, 0.765200538292127, 0.7587690617106562, 0.7530313801293684, 0.7480092202853045, 0.7437243535090562, 0.74019860224711, 0.7374538465682956, 0.7355120305984386, 0.7343951688268837, 0.7341253522283052, 0.7347247541431304, 0.736215635859997, 0.7386203518439208, 0.7419613545542819, 0.7462611987973471, 0.7515425455588107, 0.7578281652627885, 0.7651409404047979, 0.7735038675075371, 0.7829400583497098, 0.7934727404197292, 0.8051252565478845, 0.8179210636724573, 0.8318837306973037, 0.8470369354006207, 0.8634044603569266, 0.8810101878367418, 0.8998780936510414, 0.9200322399102412, 0.941496766670301, 0.9642958824414479, 0.9884538535380383, 1.0139949922512053, 1.0409436438291224, 1.0693241722530011, 1.099160944800312, 1.13047831539008, 1.1633006067086455, 1.1976520911177275, 1.2335569703502347, 1.2710393540028235, 1.3101232368377973, 1.3508324749106215, 1.393190760542843, 1.4372215961639214, 1.482948267049016, 1.5303938129833674, 1.5795809988874543, 1.6305322844406103, 1.6832697927442146, 1.7378152780690033, 1.794190092734298, 1.852415153170279, 1.9125109052174913, 1.974497288720903, 2.0383937014787525, 2.104218962609268, 2.171991275401061, 2.241728189715604, 2.313446564012635, 2.3871625270716383, 2.4628914394847428, 2.5406478549983036, 2.62044548178239, 2.7022971437088907, 2.7862147417206105, 2.8722092153748893, 2.9602905046464585, 3.0504675120751283, 3.142748065344651, 3.23713888037958, 3.3336455250472343, 3.4322723835520907, 3.533022621609596, 3.635898152486329, 3.740899603992609, 3.848026286513144, 3.95727616216012 ...

# %% [markdown]
# # plot Candlesticks chart for the stocks

# %%
trace = go.Candlestick(x=dataDF.Date,
                       open=dataDF.Open,
                       high=dataDF.High,
                       low=dataDF.Low,
                       close=dataDF.Close)
layout = {'title': 'AAPL Stock Prices',
         'yaxis': {'title': 'stock prices'}}
data = [trace]
fig = dict(data=data, layout=layout)
iplot(fig, filename="APPL_CandleStick")
# Out:
# <div id="69b559c1-e708-47d4-81de-a81d645e3957" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("69b559c1-e708-47d4-81de-a81d645e3957", [{"uid": "db3a7b8f-9ca9-11e8-8366-d053494eb1af", "type": "candlestick", "high": [190.679993, 191.279999, 189.779999, 191.41000400000001, 191.83999599999999, 192.649994, 191.869995, 191.800003, 192.550003, 192.429993, 191.96000700000002, 193.66000400000001, 194.850006, 195.96000700000002, 195.190002, 192.199997, 192.139999, 201.759995, 208.380005, 208.740005, 209.25], "low": [189.300003, 190.179993, 187.610001, 189.309998, 190.899994, 190.419998, 189.199997, 189.929993, 189.690002, 190.169998, 189.559998, 192.050003, 192.429993, 193.610001, 190.100006, 189.070007, 189.33999599999999, 197.309998, 200.350006, 205.479996, 207.070007], "close": [190.580002, 190.350006, 187.880005, 191.029999, 191.330002, 190.91000400000001, 191.449997, 190.399994, 191.880005, 191.440002, 191.610001, 193.0, 194.820007, 194.21000700000002, 190.979996, 189.91000400000001, 190.28999299999998, 201.5, 207.389999, 207.990005, 209.070007], "x": ["2018-07-09", "2018-07-10", "2018-07-11", "2018-07-12", "2018-07-13", "2018-07-16", "2018-07-17", "2018-07-18", "2018-07-19", "2018-07-20", "2018-07-23", "2018-07-24", "2018-07-25", "2018-07-26", "2018-07-27", "2018-07-30", "2018-07-31", "2018-08-01", "2018-08-02", "2018-08-03", "2018-08-06"], "open": [189.5, 190.71000700000002, 188.5, 189.529999, 191.080002, 191.520004, 189.75, 191.779999, 189.690002, 191.779999, 190.679993, 192.449997, 193.059998, 194.610001, 194.990005, 191.899994, 190.300003, 199.130005, 200.580002, 207.029999, 208.0]}], {"title": "AAPL Stock Prices", "yaxis": {"title": "stock prices"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
